# %%
import os
import sys
import random
import math
import numpy as np
import mxnet as mx
import skimage.io
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt

# %%
net = model_zoo.get_model('yolo3_darknet53_coco', pretrained= True,root=r'D:\COCO\coco\'')

# %%
im_fname = utils.download('https://raw.githubusercontent.com/zhreshold/' +
                          'mxnet-ssd/master/data/demo/dog.jpg',
                          path='dog.jpg')
print(im_fname)
# Out:
# dog.jpg

# %%
#im_fname = utils.download('D:/COCO/coco/val2017/', path=random.choice(file_names))
IMAGE_DIR = os.path.join(os.path.abspath("../"),"train2017")
file_names = next(os.walk(IMAGE_DIR))[2]
im_lol=random.choice(file_names)

x, img = data.transforms.presets.yolo.load_test(IMAGE_DIR+"/"+ im_lol)
print('Shape of pre-processed image:', x.shape)
# Out:
# Shape of pre-processed image: (1, 3, 416, 625)

# %%
print(img.shape)
plt.imshow(img)
# Out:
# (416, 625, 3)

# %%
class_IDs, scores, bounding_boxs = net(x)

ax = utils.viz.plot_bbox(img, bounding_boxs[0], scores[0],
                         class_IDs[0], class_names=net.classes)
plt.show()

# %%
net.classes
